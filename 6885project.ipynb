# %%
# !git clone https://github.com/junxiaosong/AlphaZero_Gomoku.git
# Out:
# Cloning into 'AlphaZero_Gomoku'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 187 (delta 81), reused 69 (delta 67), pack-reused 89 (from 1)
# Receiving objects: 100% (187/187), 8.09 MiB | 15.75 MiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/6885 project
# Out:
# /content/drive/MyDrive/6885 project

# %%
# !ls
# Out:
# AlphaZero_Gomoku	  current_policy.weights.h5  playout400.gif		     __pycache__
# best_policy_6_6_4.model   game.py		     policy_value_net_keras.py	     README.md
# best_policy_6_6_4.model2  human_play.py		     policy_value_net_numpy.py	     train.py
# best_policy_8_8_5.model   LICENSE		     policy_value_net.py
# best_policy_8_8_5.model2  mcts_alphaZero.py	     policy_value_net_pytorch.py
# best_policy.weights.h5	  mcts_pure.py		     policy_value_net_tensorflow.py

# %%
# %cd AlphaZero_Gomoku
# Out:
# /content/drive/MyDrive/6885 project/AlphaZero_Gomoku

# %%
# !pip install numpy keras tensorflow
# !pip install theano
# !pip install Lasagne

# %%
import tensorflow as tf
print(tf.__version__)  # 应输出 2.x
import numpy as np
print(np.__version__)
# Out:
# 2.17.1
# 1.26.4

# %%
# !python train.py
# Out:
# 2024-12-15 04:49:28.292864: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-15 04:49:28.314058: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-15 04:49:28.324570: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-15 04:49:29.411555: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python human_play.py
# Out:
# 2024-12-15 04:48:44.371108: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-15 04:48:44.409141: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-15 04:48:44.420647: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-15 04:48:46.017305: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
