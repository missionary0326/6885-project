# %%
# !git clone https://github.com/junxiaosong/AlphaZero_Gomoku.git
# Out:
# Cloning into 'AlphaZero_Gomoku'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 187 (delta 81), reused 69 (delta 67), pack-reused 89 (from 1)
# Receiving objects: 100% (187/187), 8.09 MiB | 15.75 MiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/6885 project
# Out:
# /content/drive/MyDrive/6885 project

# %%
# !ls
# Out:
# best_policy_6_6_4.model   current_policy.weights.h5  mcts_pure.py		     README.md
# best_policy_6_6_4.model2  game.py		     playout400.gif		     training.log
# best_policy_8_8_5.model   human_play.py		     policy_value_net.py	     train.py
# best_policy_8_8_5.model2  LICENSE		     policy_value_net_tensorflow.py
# best_policy.weights.h5	  mcts_alphaZero.py	     __pycache__

# %%
# %cd AlphaZero_Gomoku
# Out:
# /content/drive/MyDrive/6885 project/AlphaZero_Gomoku

# %%
# !pip install numpy keras tensorflow
# !pip install theano
# !pip install Lasagne
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 39.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for theano: filename=Theano-1.0.5-py3-none-any.whl size=2668112 sha256=caa72b0e87dff1a33a8352ba349806e6dd07249ae5f992565792876e80fc3e56
#   Stored in directory: /root/.cache/pip/wheels/d9/e6/7d/2267d21a99e4ab8276f976f293b4ff23f50c9d809f4a216ebb
# Successfully built theano
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.1/125.1 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for Lasagne: filename=Lasagne-0.1-py3-none-any.whl size=79265 sha256=89e004528bbc522386d8d5de7cb2cb389b4cd2c186f479ae24ae18306a1c49ef
#   Stored in directory: /root/.cache/pip/wheels/26/22/9f/1512e23c2556397304b730376ae4a7b34c5a6e8d68c1273917
# Successfully built Lasagne
# ...

# %%
import tensorflow as tf
print(tf.__version__)  # 应输出 2.x
import numpy as np
print(np.__version__)
# !nvidia-smi
# Out:
# 2.17.1
# 1.26.4
# Sun Dec 15 05:53:04 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !sudo apt-key del 7fa2af80
# !sudo apt-key adv --fetch-keys https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64/3bf863cc.pub
# !echo "deb https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64/ /" | sudo tee /etc/apt/sources.list.d/nvidia.list

# !sudo apt-get update
# !sudo apt-get install -y tensorrt
# !sudo apt-get install -y python3-pycuda python3-libnvinfer

# !dpkg -l | grep TensorRT
# Out:
# ...
# OK
# ...
# Executing: /tmp/apt-key-gpghome.VY4wnahlir/gpg.1.sh --fetch-keys https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64/3bf863cc.pub
# gpg: requesting key from 'https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64/3bf863cc.pub'
# gpg: key A4B469963BF863CC: public key "cudatools <cudatools@nvidia.com>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# deb https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64/ /
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1,581 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [1,890 kB]
# ...

# %%
# !python train.py
# Out:
# 2024-12-15 05:53:13.152282: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-15 05:53:13.172855: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-15 05:53:13.178596: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-15 05:53:14.245783: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python human_play.py
# Out:
# 2024-12-15 04:48:44.371108: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-15 04:48:44.409141: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-15 04:48:44.420647: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-15 04:48:46.017305: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
